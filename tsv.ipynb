# %%
#tsv파일 pandas로 데이터프레임 확인
import pandas as pd
df = pd.read_csv('gutenberg_books.tsv', sep='\t')

# %%
df
# Out:
#         ID                                    Title  \
# 0       84  Frankenstein; Or, The Modern Prometheus
# 1     1342                      Pride and Prejudice
# 2     2701                 Moby Dick; Or, The Whale
# 3     1513                         Romeo and Juliet
# 4      145                              Middlemarch
# ..     ...                                      ...
# 883   2048       The Sketch-Book of Geoffrey Crayon
# 884   1642                                Euthyphro
# 885   6923                                The Miser
# 886   2151  The Works of Edgar Allan Poe — Volume 5
# 887  17957                           On the Sublime
#
#                           Author  Year  \
# 0    Mary Wollstonecraft Shelley  1993
# 1                    Jane Austen  1998
# 2                Herman Melville  2001
# 3            William Shakespeare  1998
# 4                   George Eliot  1994
# ..                           ...   ...
# 883            Washington Irving  2000
# ...

# %%
# Author에서 balzac 검색
df[df['Author'].str.contains('balzac', case=False)]
# Out:
# Empty DataFrame
# Columns: [ID, Title, Author, Year, Text]
# Index: []
